# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print('ran')
# Out:
# ran

# %%
bureau=pd.read_csv("C:\\Users\\dbda\\Desktop\\bureau.csv")
print("Shape of training data: {}".format(bureau.shape))
# Out:
# Shape of training data: (1716428, 17)

# %%
bureau.drop('SK_ID_CURR', inplace=True, axis=1)
bureau.drop('SK_ID_BUREAU', inplace=True, axis=1)
print("Shape of training data: {}".format(bureau.shape))
# Out:
# Shape of training data: (1716428, 15)

# %%
df = pd.DataFrame(bureau)

# %%
df
# Out:
#         CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# 0              Closed      currency 1         -497                   0
# 1              Active      currency 1         -208                   0
# 2              Active      currency 1         -203                   0
# 3              Active      currency 1         -203                   0
# 4              Active      currency 1         -629                   0
# 5              Active      currency 1         -273                   0
# 6              Active      currency 1          -43                   0
# 7              Closed      currency 1        -1896                   0
# 8              Closed      currency 1        -1146                   0
# 9              Active      currency 1        -1146                   0
# 10             Active      currency 1        -1146                   0
# 11             Closed      currency 1        -2456                   0
# ...

# %%
df['CREDIT_ACTIVE'] =df['CREDIT_ACTIVE'].astype('category').cat.codes
df['CREDIT_CURRENCY'] =df['CREDIT_CURRENCY'].astype('category').cat.codes
df['CREDIT_TYPE'] =df['CREDIT_TYPE'].astype('category').cat.codes

# %%
df
# Out:
#          CREDIT_ACTIVE  CREDIT_CURRENCY  DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# 0                    2                0         -497                   0
# 1                    0                0         -208                   0
# 2                    0                0         -203                   0
# 3                    0                0         -203                   0
# 4                    0                0         -629                   0
# 5                    0                0         -273                   0
# 6                    0                0          -43                   0
# 7                    2                0        -1896                   0
# 8                    2                0        -1146                   0
# 9                    0                0        -1146                   0
# 10                   0                0        -1146                   0
# 11                   2                0        -2456                   0
# ...

# %%
df[df.columns[1:]].corr()['AMT_CREDIT_SUM'][:]
# Out:
# CREDIT_CURRENCY           0.100223
# DAYS_CREDIT               0.050883
# CREDIT_DAY_OVERDUE       -0.003292
# DAYS_CREDIT_ENDDATE       0.055424
# DAYS_ENDDATE_FACT         0.059096
# AMT_CREDIT_MAX_OVERDUE    0.081663
# CNT_CREDIT_PROLONG       -0.008345
# AMT_CREDIT_SUM            1.000000
# AMT_CREDIT_SUM_DEBT       0.683419
# AMT_CREDIT_SUM_LIMIT      0.003756
# AMT_CREDIT_SUM_OVERDUE    0.006342
# CREDIT_TYPE               0.286320
# DAYS_CREDIT_UPDATE        0.104629
# AMT_ANNUITY               0.049146
# Name: AMT_CREDIT_SUM, dtype: float64
